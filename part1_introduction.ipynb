# %%
# Install necessary packages
# %pip install -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt
# Out:
# Requirement already satisfied: pandas<3.0,>=1.5 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 2)) (2.2.3)
# Requirement already satisfied: numpy<3.0,>=1.20 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 3)) (1.23.5)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 4)) (1.5.2)
# Requirement already satisfied: xgboost<3.0,>=1.5 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: imbalanced-learn<1.0,>=0.9 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 6)) (0.12.4)
# Requirement already satisfied: matplotlib<4.0,>=3.5 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (3.7.0)
# Requirement already satisfied: seaborn<1.0,>=0.11 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 8)) (0.13.0)
# Requirement already satisfied: ipykernel in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from -r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (6.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from pandas<3.0,>=1.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from pandas<3.0,>=1.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 2)) (2022.7)
# Requirement already satisfied: tzdata>=2022.7 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from pandas<3.0,>=1.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from scikit-learn<2.0,>=1.0->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from scikit-learn<2.0,>=1.0->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 4)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from scikit-learn<2.0,>=1.0->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from matplotlib<4.0,>=3.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 7)) (3.0.9)
# Requirement already satisfied: appnope in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: debugpy>=1.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (1.5.6)
# Requirement already satisfied: psutil in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (6.1)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (5.7.1)
# Requirement already satisfied: backcall in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: decorator in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (2.16.1)
# Requirement already satisfied: stack-data in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (4.8.0)
# Requirement already satisfied: entrypoints in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (5.2.0)
# Requirement already satisfied: six>=1.5 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.5->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (2.5.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.2.5)
# Requirement already satisfied: executing in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (2.0.1)
# Requirement already satisfied: asttokens in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/hteshome/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r /Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/requirements.txt (line 9)) (0.2.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Part 1: Introduction to Classification & Evaluation

#Objective: Load the synthetic health data, train a Logistic Regression model, and evaluate its performance.

## 1. Setup

#Import necessary libraries.

import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix
from sklearn.impute import SimpleImputer
import json

# %%
## 2. Data Loading

#Implement the `load_data` function to read the dataset.

def load_data(file_path):
    """
    Load the synthetic health data from a CSV file.
    
    Args:
        file_path: Path to the CSV file
        
    Returns:
        DataFrame containing the data
    """
    
    return pd.read_csv(file_path)

# %%
## 3. Data Preparation

#Implement `prepare_data_part1` to select features, split data, and handle missing values.

def prepare_data_part1(df, test_size=0.2, random_state=42):
    """
    Prepare data for modeling: select features, split into train/test sets, handle missing values.
    
    Args:
        df: Input DataFrame
        test_size: Proportion of data for testing
        random_state: Random seed for reproducibility
        
    Returns:
        X_train, X_test, y_train, y_test
    """
    features = ['age', 'systolic_bp', 'diastolic_bp', 'glucose_level', 'bmi']
    target = 'disease_outcome'
    
    X = df[features]
    y = df[target]
    
    imputer = SimpleImputer(strategy='mean')
    X_imputed = imputer.fit_transform(X)
    
    return train_test_split(X_imputed, y, test_size=test_size, random_state=random_state)

# %%
## 4. Model Training

#Implement `train_logistic_regression`.

def train_logistic_regression(X_train, y_train):
    """
    Train a logistic regression model.
    
    Args:
        X_train: Training features
        y_train: Training target
        
    Returns:
        Trained logistic regression model
    """
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)
    return model

# %%
## 5. Model Evaluation

#Implement `calculate_evaluation_metrics` to assess the model's performance.

def calculate_evaluation_metrics(model, X_test, y_test):
    """
    Calculate classification evaluation metrics.
    
    Args:
        model: Trained model
        X_test: Test features
        y_test: Test target
        
    Returns:
        Dictionary containing accuracy, precision, recall, f1, auc, and confusion_matrix
    """
    y_pred = model.predict(X_test)
    y_prob = model.predict_proba(X_test)[:, 1]
    
    return {
        'accuracy': accuracy_score(y_test, y_pred),
        'precision': precision_score(y_test, y_pred),
        'recall': recall_score(y_test, y_pred),
        'f1': f1_score(y_test, y_pred),
        'auc': roc_auc_score(y_test, y_prob),
        'confusion_matrix': confusion_matrix(y_test, y_pred).tolist()
    }

# %%
## 6. Save Results

#Save the calculated metrics to a text file.

def save_results(metrics, filename='/Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/results/results_part1.txt'):
    """
    Save metrics dictionary to a text file in JSON format.
    """
    with open(filename, 'w') as f:
        json.dump(metrics, f, indent=4)

# %%
## 7. Main Execution

#Run the complete workflow.

# Main execution
if __name__ == "__main__":
    # 1. Load data
    data_file = '/Users/hteshome/Desktop/5-put-a-label-on-it-haile-teshome/data/synthetic_health_data.csv'
    df = load_data(data_file)
    
    # 2. Prepare data
    X_train, X_test, y_train, y_test = prepare_data_part1(df)
    
    # 3. Train model
    model = train_logistic_regression(X_train, y_train)
    
    # 4. Evaluate model
    metrics = calculate_evaluation_metrics(model, X_test, y_test)
    
    # 5. Print metrics
    for metric, value in metrics.items():
        if metric != 'confusion_matrix':
            print(f"{metric}: {value:.4f}")
    
    # 6. Save results
    save_results(metrics)
    
    # 7. Interpret results
    interpretation = interpret_results(metrics)
    print("\nResults Interpretation:")
    for key, value in interpretation.items():
        print(f"{key}: {value}")
# Out:
# accuracy: 0.9168
# precision: 0.6615
# recall: 0.3007
# f1: 0.4135
# auc: 0.9084
#
# Results Interpretation:
# best_metric: accuracy
# worst_metric: recall
# imbalance_impact_score: 0.56

# %%
## 8. Interpret Results

#Implement a function to analyze the model performance on imbalanced data.

def interpret_results(metrics):
    """
    Analyze model performance on imbalanced data.
    
    Args:
        metrics: Dictionary containing evaluation metrics
        
    Returns:
        Dictionary with keys:
        - 'best_metric': Name of the metric that performed best
        - 'worst_metric': Name of the metric that performed worst
        - 'imbalance_impact_score': A score from 0-1 indicating how much
          the class imbalance affected results (0=no impact, 1=severe impact)
    """
    metric_values = {k: v for k, v in metrics.items() if k != 'confusion_matrix'}
    best_metric = max(metric_values, key=metric_values.get)
    worst_metric = min(metric_values, key=metric_values.get)
    
    imbalance_impact_score = float(
        abs(metrics['accuracy'] - metrics['recall'] + metrics['accuracy'] - metrics['f1']) / 2
    )
    
    imbalance_impact_score = min(1.0, round(imbalance_impact_score, 3))  

    return {
        'best_metric': best_metric,
        'worst_metric': worst_metric,
        'imbalance_impact_score': imbalance_impact_score
    }
